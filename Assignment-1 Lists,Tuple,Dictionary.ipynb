# %%
print("SubTopic: Lists")
students = ["Aarav", "Isha", "Rohan", "Sneha", "Kabir"]

print("1. Display the third student's name")
print("Third student:", students[2])

print('2. Change "Rohan" to "Rohan Patil"')
students[2] = "Rohan Patil"

print('3. Add new students "Ananya" and "Vihaan"')
students.extend(["Ananya", "Vihaan"])

print("4. Remove 'Kabir'' from the list")
students.remove("Kabir")

print("5. Display the total number of registered students")
print("Total registered students:", len(students))

print("6. Check whether 'Isha' is registered")
if "Isha" in students:
    print("Isha is registered.")
else:
    print("Isha is not registered.")

print("7. Arrange the list in alphabetical order")
sorted_students = students.sort()
print(sorted_students)

print("8. Create a copy of the final student list")
backup_students = students.copy()
print(backup_students)

print("9. AI Hackathon participants")
hackathon = ["Meera", "Arjun", "Isha"]
print(hackathon)

all_participants = students + hackathon
print(all_participants)

print("10. Display the final lists")

print("\nFinal Tech Fest Student List:")
print(students)
print("\nBackup Student List:")
print(backup_students)
print("\nCombined Participant List:")
print(all_participants)
# Out:
# 1. Display the third student's name
# Third student: Rohan
# 2. Change "Rohan" to "Rohan Patil"
# 3. Add new students "Ananya" and "Vihaan"
# 4. Remove 'Kabir'' from the list
# 5. Display the total number of registered students
# Total registered students: 6
# 6. Check whether 'Isha' is registered
# Isha is registered.
# 7. Arrange the list in alphabetical order
# None
# 8. Create a copy of the final student list
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan']
# 9. AI Hackathon participants
# ['Meera', 'Arjun', 'Isha']
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan', 'Meera', 'Arjun', 'Isha']
# 10. Display the final lists
#
# Final Tech Fest Student List:
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan']
#
# Backup Student List:
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan']
#
# Combined Participant List:
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan', 'Meera', 'Arjun', 'Isha']

# %%
print("SubTopic: Tuples")
courses = ("Python", "Data Science", "Cloud Computing", "Cyber Security", "AI")

print("1. Display the second course selected by the student.")
print(courses[1]) #Data Science

print("2. Display the last two courses using tuple slicing.")
print(courses[-2:])

print("3. Check whether 'python' is present in tuple")
if "Python" in courses:
    print("Python is present")
else:
    print("Python is not present")

print("4. Find the position (index) of 'Cloud Computing'.")
print("Index of 'Cloud Computing' is:", courses.index("Cloud Computing"))

print("5. Find the total number of courses selected.")
print("Total number of courses:", len(courses))

print("6.The student decides to additionally enroll in 'Machine Learning' and 'Web Development'.")
courses = courses + ("Machine Learning", "Web Developement") 
print(courses)

print(" 7. Remove 'Cyber Security' by creating a new tuple")
courses = tuple(course for course in courses if course != 'Cyber Security')
print(courses)

print("8. Arrange courses alphabetically")
sorted_courses = tuple(sorted(courses))
print(sorted_courses)

print("9. Create a backup copy")
backup_courses = sorted_courses
print(backup_courses)

print("10. Friend Courses are:")
friend_courses = ("AI", "Blockchain", "Python")
print(friend_courses)

print("11. Combine the student's courses and friend's courses into a new tuple called combined_courses.")
combined_courses = courses + friend_courses
print(combined_courses)

print("Display final results") 

print("\nFinal course tuple:", courses)
print("Sorted course tuple:", sorted_courses)
print("Backup tuple:", backup_courses)
print("Combined tuple:", combined_courses)
# Out:
# SubTopic: Tuples
# 1. Display the second course selected by the student.
# Data Science
# 2. Display the last two courses using tuple slicing.
# ('Cyber Security', 'AI')
# 3. Check whether 'python' is present in tuple
# Python is present
# 4. Find the position (index) of 'Cloud Computing'.
# Index of 'Cloud Computing' is: 2
# 5. Find the total number of courses selected.
# Total number of courses: 5
# 6.The student decides to additionally enroll in 'Machine Learning' and 'Web Development'.
# ('Python', 'Data Science', 'Cloud Computing', 'Cyber Security', 'AI', 'Machine Learning', 'Web Developement')
#  7. Remove 'Cyber Security' by creating a new tuple
# ('Python', 'Data Science', 'Cloud Computing', 'AI', 'Machine Learning', 'Web Developement')
# 8. Arrange courses alphabetically
# ('AI', 'Cloud Computing', 'Data Science', 'Machine Learning', 'Python', 'Web Developement')
# 9. Create a backup copy
# ...

# %%
print("SubTopic: Dictionary")
print("Dictionary of Ford Mustang details")

dict1 = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964,
    "color": "Red",
    "fuel_type": "Petrol"
}

print("1. Accessing a value")
model_name = dict1["model"]
print("Model Name:", model_name)

print("2. Get keys")
keys = dict1.keys()
dict1["price"] = 5000000
print("Keys:", list(keys))

print("3. Get values")
values = dict1.values()
dict1["color"] = "Black"
print("Values:", list(values))

print("4. Get items")
items = dict1.items()
dict1["fuel_type"] = "Petrol Engine"
print("Key-Value Pairs:", list(items))

print("5. Check if a key exists")
if "brand" in dict1:
    print("Brand is present in the dictionary.")
else:
    print("Brand is not present in the dictionary.")

if "owner" in dict1:
    print("Owner is present in the dictionary.")
else:
    print("Owner is not present in the dictionary.")

print("6. Updating Dictionary")
dict1.update({"transmission": "Manual"})
print("Updated Dictionary:", dict1)

print("7. Removing items by pop()")
dict1.pop("price")
print("After Removing Price:", dict1)

dict1.popitem()
print("After Removing Last Item:", dict1)

print("8. Copying a dictionary")
dict1_copy = dict1.copy()
print("Copied Dictionary:", dict1_copy)

print("9. Nesting dictionaries")
engine = {
    "type": "V8",
    "horsepower": 271,
    "fuel": "Petrol"
}

dict1["engine_details"] = engine
print("Dictionary with Nested Dictionary:", dict1)

print("10. Clearing a dictionary")
dict1.clear()
print("After Clearing the Dictionary:", dict1)
# Out:
# SubTopic: Dictionary
# Dictionary of Ford Mustang details
# 1. Accessing a value
# Model Name: Mustang
# 2. Get keys
# Keys: ['brand', 'model', 'year', 'color', 'fuel_type', 'price']
# 3. Get values
# Values: ['Ford', 'Mustang', 1964, 'Black', 'Petrol', 5000000]
# 4. Get items
# Key-Value Pairs: [('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'Black'), ('fuel_type', 'Petrol Engine'), ('price', 5000000)]
# 5. Check if a key exists
# Brand is present in the dictionary.
# Owner is not present in the dictionary.
# 6. Updating Dictionary
# Updated Dictionary: {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'Black', 'fuel_type': 'Petrol Engine', 'price': 5000000, 'transmission': 'Manual'}
# 7. Removing items by pop()
# After Removing Price: {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'Black', 'fuel_type': 'Petrol Engine', 'transmission': 'Manual'}
# ...
